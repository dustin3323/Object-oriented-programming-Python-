# %%
from tkinter import *
from tkinter import ttk

# toolkit inter

# %%
# Graphical User Interface

# %%
button = ttk.Button()  # ttk带主题的控件
button.pack()  # 堆在父窗口（主窗口）
button['text'] = 'Click me!'

mainloop()  # 消息/事件驱动 event-driven program

# %%
# on_click
def on_click():
    print('hello')

button = ttk.Button()  
button.pack()  
button['text'] = 'Click me!'
button['command'] = on_click

mainloop()  # 消息/事件驱动 event-driven program 响应按钮点击事件
# Out:
# hello
# hello

# %%
# Button 
for i in range(10):
    ttk.Button(text=i).pack() # ttk: themed tool kit 带主题的，为了美观
    
mainloop()

# %%
# pack()
for i in range(10):
    ttk.Button(text=i).pack(fill=X, expand=True) # fill = X, Y, BOTH
    
mainloop()

# %%
# pack()
for i in range(10):
    ttk.Button(text=i).pack(side=LEFT, fill=X, expand=True) # fill = X, Y, BOTH
    
mainloop()

# %%
# label
def on_click():
    label(text='clicked')

# ttk.Label(text='hello').pack()
label = ttk.Label(text='hello')
label.pack()
button = ttk.Button()  
button.pack()  
button['text'] = 'Click me!'
button['command'] = on_click

mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Sue\Anaconda3\lib\tkinter\__init__.py", line 1699, in __call__
#     return self.func(*args)
#   File "<ipython-input-13-fddcd0e7c85a>", line 3, in on_click
#     label(text='clicked')
# TypeError: 'Label' object is not callable
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Sue\Anaconda3\lib\tkinter\__init__.py", line 1699, in __call__
#     return self.func(*args)
#   File "<ipython-input-13-fddcd0e7c85a>", line 3, in on_click
#     label(text='clicked')
# TypeError: 'Label' object is not callable

# %%
for i in range(4):
    for j in range(5):
        text = '{}.{}'.format(i,j)
        ttk.Button(text=text).grid(row=i,column=j)
        
mainloop()

# %%
from tkinter import *
from tkinter import ttk
from enum import Enum

class State(Enum):
    calculated = 0
    in_number1 = 1
    post_operator = 2
    in_number2 = 3

class Calculator(Tk):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.title('Simple Calculator')
        self.geometry('400x600')
        
        self.result_string = StringVar()
        self.result_string.set('0')
        self.nmuber1 = '0'
        self.number2 = None
        self.operator = None
        self.state = State.calculated
        
#         Output
        output = ttk.Label(self, textvariable=self.result_string, 
                           font=('TKDefaultFont', 48), anchor=E)
        output.pack(side=TOP, expand=True, fill=BOTH)

#         row 1
        row = Frame(self)
        row.pack(side=TOP, expand=True, fill=BOTH)
        self.add_button(row, 'CE', self.on_ce_click)
        self.add_button(row, 'C', self.on_c_click)
        self.add_button(row, 'Backspace', self.on_back_click)
        self.add_button(row, '/', self.on_division_click)
#         row2
        row = Frame(self)
        row.pack(side=TOP, expand=True, fill=BOTH)
        self.add_button(row, '7', self.on_7_click)
        self.add_button(row, '8', self.on_8_click)
        self.add_button(row, '9', self.on_9_click)
        self.add_button(row, 'X', self.on_x_click)
#         row 3
        row = Frame(self)
        row.pack(side=TOP, expand=True, fill=BOTH)
        self.add_button(row, '4', self.on_4_click)
        self.add_button(row, '5', self.on_5_click)
        self.add_button(row, '6', self.on_6_click)
        self.add_button(row, '-', self.on_minus_click)
        
#         row 4
        row = Frame(self)
        row.pack(side=TOP, expand=True, fill=BOTH)
        self.add_button(row, '1', self.on_1_click)
        self.add_button(row, '2', self.on_2_click)
        self.add_button(row, '3', self.on_3_click)
        self.add_button(row, '+', self.on_plus_click)
        
#         row 5
        row = Frame(self)
        row.pack(side=TOP, expand=True, fill=BOTH)
        self.add_button(row, '+/-', self.on_nega_click)
        self.add_button(row, '0', self.on_0_click)
        self.add_button(row, '.', self.on_dot_click)
        self.add_button(row, '=', self.on_equal_click)
        

            
    def add_button(self, parent, text=None, command=None):
        button = ttk.Button(parent, text=text, command=command)
        button.pack(side=LEFT,expand=True, fill=BOTH)
    
    def on_ce_click(self):
        print('ce clicked')
        
    def on_c_click(self):
        print('c clicked')
        
    def on_back_click(self):
        print('back clicked')
        
    def on_operator(self, operator):
        if self.state == State.calculated:
            self.state = State.post_operator
        elif self.state == State.in_number1:  # 正在输入第一个数字
            self.state = State.post_operator
#         elif self.state == State.post_operator:  
        elif self.state == State.in_number2:
            self.on_equal_click()
            self.state = State.post_operator
        else: assert(0)
        
        self.operator = operator
    
    def on_division_click(self):
        self.on_operator('/')
        print('/ clicked')
        
    def on_plus_click(self):
        self.on_operator('+')
        print('plus clicked')
        
    def on_minus_click(self):
        self.on_operator('-')
        print('minus clicked')
        
    def on_x_click(self):
        self.on_operator('*')
        print('multiply clicked')
        
    def on_dot_click(self):
        self.on_number('.')
        print('dot clicked')
        
    def on_nega_click(self):
        print('+/- clicked')
        
    def on_equal_click(self):
        if self.state != State.in_number2:
            return
        print('equal clicked')
        if self.operator == '+':
            self.number1 = str(float(self.number1) + float(self.number2))
        elif self.operator == '-':
            self.number1 = str(float(self.number1) - float(self.number2))
        elif self.operator == '*':
            self.number1 = str(float(self.number1) * float(self.number2))
        elif self.operator == '/':
            self.number1 = str(float(self.number1) / float(self.number2))
        self.result_string.set(self.number1)
        self.state = State.calculated
        
    def on_0_click(self):
        print('0 clicked')
        self.on_number('0')
        
    def on_1_click(self):
        self.on_number('1')
        print('1 clicked')
        
    def on_2_click(self):
        self.on_number('2')
        print('2 clicked')
        
    def on_3_click(self):
        self.on_number('3')
        print('3 clicked')
        
    def on_4_click(self):
        self.on_number('4')
        print('4 clicked')
        
    def on_5_click(self):
        self.on_number('5')
        print('5 clicked')
        
    def on_6_click(self):
        self.on_number('6')
        print('6 clicked')
        
    def on_7_click(self):
        self.on_number('7')
        print('7 clicked')
        
    def on_8_click(self):
        self.on_number('8')
        print('8 clicked')
        
    def on_9_click(self):
        self.on_number('9')
        print('9 clicked')
        
    def on_number(self, ch):
        if self.state == State.calculated:
            self.number1 = ch
            self.state = State.in_number1
            self.result_string.set(self.number1)
        elif self.state == State.in_number1:  # 正在输入第一个数字
            self.number1 = self.number1 + ch
            self.result_string.set(self.number1)
        elif self.state == State.post_operator:
            self.number2 = ch
            self.state = State.in_number2
            self.result_string.set(self.number2)
        elif self.state == State.in_number2:
            self.number2 = self.number2 + ch
            self.result_string.set(self.number2)
        else: assert(0)
        
    
if __name__=='__main__':
    app = Calculator()
    app.mainloop()
# Out:
# 9 clicked
# multiply clicked
# 6 clicked
# equal clicked
# 6 clicked
# multiply clicked
# 9 clicked
# equal clicked
# minus clicked
# 3 clicked
# equal clicked
# ce clicked

# %%
from tkinter import *
from tkinter import ttk
from enum import Enum

class State(Enum):
    calculated = 0
    in_number1 = 1
    post_operator = 2
    in_number2 = 3

class Calculator(Tk):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.title('Simple Calculator')
        self.geometry('400x600')
        
        self.result_string = StringVar()
        self.result_string.set('0')
        self.nmuber1 = '0'
        self.number2 = None
        self.operator = None
        self.state = State.calculated
        
#         Output
        output = ttk.Label(self, textvariable=self.result_string, 
                           font=('TKDefaultFont', 48), anchor=E)
        output.pack(side=TOP, expand=True, fill=BOTH)

#         row 1
        row = Frame(self)
        row.pack(side=TOP, expand=True, fill=BOTH)
        self.add_button(row, 'CE', self.on_ce_click)
        self.add_button(row, 'C', self.on_c_click)
        self.add_button(row, 'Backspace', self.on_back_click)
        self.add_button(row, '/', self.on_division_click)
#         row2
        row = Frame(self)
        row.pack(side=TOP, expand=True, fill=BOTH)
        self.add_button(row, '7', self.gen_on_number_click('7'))
        self.add_button(row, '8', self.gen_on_number_click('8'))
        self.add_button(row, '9', self.gen_on_number_click('9'))
        self.add_button(row, 'X', self.on_x_click)
#         row 3
        row = Frame(self)
        row.pack(side=TOP, expand=True, fill=BOTH)
        self.add_button(row, '4', self.gen_on_number_click('4'))
        self.add_button(row, '5', self.gen_on_number_click('5'))
        self.add_button(row, '6', self.gen_on_number_click('6'))
        self.add_button(row, '-', self.on_minus_click)
        
#         row 4
        row = Frame(self)
        row.pack(side=TOP, expand=True, fill=BOTH)
#         self.add_button(row, '1', self.on_1_click)
        self.add_button(row, '1', self.gen_on_number_click('1'))
        self.add_button(row, '2', self.gen_on_number_click('2'))
        self.add_button(row, '3', self.gen_on_number_click('3'))
        self.add_button(row, '+', self.on_plus_click)
        
#         row 5
        row = Frame(self)
        row.pack(side=TOP, expand=True, fill=BOTH)
        self.add_button(row, '+/-', self.on_nega_click)
        self.add_button(row, '0', self.gen_on_number_click('1'))
        self.add_button(row, '.', self.on_dot_click)
        self.add_button(row, '=', self.on_equal_click)
        

            
    def add_button(self, parent, text=None, command=None):
        button = ttk.Button(parent, text=text, command=command)
        button.pack(side=LEFT,expand=True, fill=BOTH)
    
    def on_ce_click(self):
        print('ce clicked')
        
    def on_c_click(self):
        print('c clicked')
        
    def on_back_click(self):
        print('back clicked')
        
    def on_operator(self, operator):
        if self.state == State.calculated:
            self.state = State.post_operator
        elif self.state == State.in_number1:  # 正在输入第一个数字
            self.state = State.post_operator
#         elif self.state == State.post_operator:  
        elif self.state == State.in_number2:
            self.on_equal_click()
            self.state = State.post_operator
        else: assert(0)
        
        self.operator = operator
    
    def on_division_click(self):
        self.on_operator('/')
        print('/ clicked')
        
    def on_plus_click(self):
        self.on_operator('+')
        print('plus clicked')
        
    def on_minus_click(self):
        self.on_operator('-')
        print('minus clicked')
        
    def on_x_click(self):
        self.on_operator('*')
        print('multiply clicked')
        
    def on_dot_click(self):
        self.on_number('.')
        print('dot clicked')
        
    def on_nega_click(self):
        print('+/- clicked')
        
    def on_equal_click(self):
        if self.state != State.in_number2:
            return
        print('equal clicked')
        if self.operator == '+':
            self.number1 = str(float(self.number1) + float(self.number2))
        elif self.operator == '-':
            self.number1 = str(float(self.number1) - float(self.number2))
        elif self.operator == '*':
            self.number1 = str(float(self.number1) * float(self.number2))
        elif self.operator == '/':
            self.number1 = str(float(self.number1) / float(self.number2))
        self.result_string.set(self.number1)
        self.state = State.calculated
        
#     def on_0_click(self):
#         print('0 clicked')
#         self.on_number('0')
        
    def gen_on_number_click(self, ch):
        return lambda: self.on_number(ch)
# 直接返回一个函数

#     def on_1_click(self):
#         self.on_number('1')
#         print('1 clicked')
        
        
    def on_number(self, ch):
        if self.state == State.calculated:
            self.number1 = ch
            self.state = State.in_number1
            self.result_string.set(self.number1)
        elif self.state == State.in_number1:  # 正在输入第一个数字
            self.number1 = self.number1 + ch
            self.result_string.set(self.number1)
        elif self.state == State.post_operator:
            self.number2 = ch
            self.state = State.in_number2
            self.result_string.set(self.number2)
        elif self.state == State.in_number2:
            self.number2 = self.number2 + ch
            self.result_string.set(self.number2)
        else: assert(0)
        
    
if __name__=='__main__':
    app = Calculator()
    app.mainloop()
# Out:
# plus clicked
# equal clicked
