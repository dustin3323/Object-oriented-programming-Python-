# %%
from tkinter import *
from tkinter import ttk
from enum import Enum

class State(Enum):
    calculated = 0
    in_number1 = 1
    post_operator = 2
    in_number2 = 3

class Row(Frame):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.pack(side=TOP, expand=True, fill=BOTH)
        
    def add_button(self, text=None, command=None):
        button = ttk.Button(self, text=text, command=command)
        button.pack(side=LEFT,expand=True, fill=BOTH)
        
        
    
class Calculator(Tk):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        
        self.nmuber1 = '0'
        self.number2 = None
        self.operator = None
        self.state = State.calculated
        self.setup_ui()
        
    def setup_ui(self):
        self.title('Simple Calculator')
        self.geometry('400x600')
        
        self.result_string = StringVar()
        self.result_string.set('0')
        
        
#         Output
        output = ttk.Label(self, textvariable=self.result_string, 
                           font=('TKDefaultFont', 48), anchor=E)
        output.pack(side=TOP, expand=True, fill=BOTH)

#         row 1
        Row(self).add_button('CE', self.on_ce_click)\
                 .add_button('C', self.on_c_click)\
                 .add_button('Backspace', self.on_back_click)\
                 .add_button('/', self.gen_on_operator_click('/'))
        
#         row2
        row = Row(self)
#         row.pack(side=TOP, expand=True, fill=BOTH)
        row.add_button('7', self.gen_on_number_click('7'))
        row.add_button('8', self.gen_on_number_click('8'))
        row.add_button('9', self.gen_on_number_click('9'))
        row.add_button('X', self.gen_on_operator_click('*'))

#         row 3
        row = Row(self)
#         row.pack(side=TOP, expand=True, fill=BOTH)
        row.add_button('4', self.gen_on_number_click('4'))
        row.add_button('5', self.gen_on_number_click('5'))
        row.add_button('6', self.gen_on_number_click('6'))
        row.add_button('-', self.gen_on_operator_click('-'))
        
#         row 4
        row = Row(self)
#         row.pack(side=TOP, expand=True, fill=BOTH)
#         self.add_button(row, '1', self.on_1_click)
        row.add_button('1', self.gen_on_number_click('1'))
        row.add_button('2', self.gen_on_number_click('2'))
        row.add_button('3', self.gen_on_number_click('3'))
        row.add_button('+', self.gen_on_operator_click('+'))
        
#         row 5
        row = Row(self)
#         row.pack(side=TOP, expand=True, fill=BOTH)
        row.add_button('+/-', self.on_nega_click)
        row.add_button('0', self.gen_on_number_click('1'))
        row.add_button('.', self.on_dot_click)
        row.add_button('=', self.on_equal_click)
        

            
    
    
    def on_ce_click(self):
        print('ce clicked')
        
    def on_c_click(self):
        print('c clicked')
        
    def on_back_click(self):
        print('back clicked')
        
    def on_operator(self, operator):
        print('{} clicked.'.format(operator))
        if self.state == State.calculated:
            self.state = State.post_operator
        elif self.state == State.in_number1:  # 正在输入第一个数字
            self.state = State.post_operator
#         elif self.state == State.post_operator:  
        elif self.state == State.in_number2:
            self.on_equal_click()
            self.state = State.post_operator
        else: assert(0)
        
        self.operator = operator
    
    def on_division_click(self):
        self.on_operator('/')
        print('/ clicked')
        
    def on_plus_click(self):
        self.on_operator('+')
        print('plus clicked')
        
    def on_minus_click(self):
        self.on_operator('-')
        print('minus clicked')
        
    def on_x_click(self):
        self.on_operator('*')
        print('multiply clicked')
        
    def on_dot_click(self):
        self.on_number('.')
        print('dot clicked')
        
    def on_nega_click(self):
        print('+/- clicked')
        
    def on_equal_click(self):
        if self.state != State.in_number2:
            return
        print('equal clicked')
        if self.operator == '+':
            self.number1 = str(float(self.number1) + float(self.number2))
        elif self.operator == '-':
            self.number1 = str(float(self.number1) - float(self.number2))
        elif self.operator == '*':
            self.number1 = str(float(self.number1) * float(self.number2))
        elif self.operator == '/':
            self.number1 = str(float(self.number1) / float(self.number2))
        self.result_string.set(self.number1)
        self.state = State.calculated
        
#     def on_0_click(self):
#         print('0 clicked')
#         self.on_number('0')
        
    def gen_on_number_click(self, ch):
        return lambda: self.on_number(ch)
# 直接返回一个函数

    def gen_on_operator_click(self,ch):
        return lambda: self.on_operator(ch)
    
#     def on_1_click(self):
#         self.on_number('1')
#         print('1 clicked')
        
        
    def on_number(self, ch):
        if self.state == State.calculated:
            self.number1 = ch
            self.state = State.in_number1
            self.result_string.set(self.number1)
        elif self.state == State.in_number1:  # 正在输入第一个数字
            self.number1 = self.number1 + ch
            self.result_string.set(self.number1)
        elif self.state == State.post_operator:
            self.number2 = ch
            self.state = State.in_number2
            self.result_string.set(self.number2)
        elif self.state == State.in_number2:
            self.number2 = self.number2 + ch
            self.result_string.set(self.number2)
        else: assert(0)
        
    
if __name__=='__main__':
    app = Calculator()
    app.mainloop()
#     setup_ui()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-b6b050d19272> in <module>()
#     179
#     180 if __name__=='__main__':
# --> 181     app = Calculator()
#     182     app.mainloop()
#     183 #     setup_ui()
#
# <ipython-input-10-b6b050d19272> in __init__(self, *args, **kwargs)
#      28         self.operator = None
#      29         self.state = State.calculated
# ---> 30         self.setup_ui()
#      31
#      32     def setup_ui(self):
#
# <ipython-input-10-b6b050d19272> in setup_ui(self)
#      44
#      45 #         row 1
# ---> 46         Row(self).add_button('CE', self.on_ce_click)                 .add_button('C', self.on_c_click)                 .add_button('Backspace', self.on_back_click)                 .add_button('/', self.gen_on_operator_click('/'))
#      47
#      48 #         row2
#
# AttributeError: 'NoneType' object has no attribute 'add_button'

# %%
from tkinter import *
from tkinter import ttk
from enum import Enum

class State(Enum):
    calculated = 0
    in_number1 = 1
    post_operator = 2
    in_number2 = 3

class Row(Frame):
    def __init__(self, parent, buttons, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.pack(side=TOP, expand=True, fill=BOTH)
        for button in buttons:
            ttk.Button(self, text=button[0], command=button[1])\
            .pack(side=LEFT, expand=True, fill=BOTH)
        
    def add_button(self, text=None, command=None):
        button = ttk.Button(self, text=text, command=command)
        button.pack(side=LEFT,expand=True, fill=BOTH)
        return self
        
    
class Calculator(Tk):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        
        self.nmuber1 = '0'
        self.number2 = None
        self.operator = None
        self.state = State.calculated
        self.setup_ui()
        
    def setup_ui(self):
        self.title('Simple Calculator')
        self.geometry('400x600')
        
        self.result_string = StringVar()
        self.result_string.set('0')
        
        
#         Output
        output = ttk.Label(self, textvariable=self.result_string, 
                           font=('TKDefaultFont', 48), anchor=E)
        output.pack(side=TOP, expand=True, fill=BOTH)

#         row 1
        Row(self,[('CE', self.on_ce_click),
                 ('C', self.on_c_click),
                 ('Backspace', self.on_back_click),
                 ('/', self.gen_on_operator_click('/'))])
                
#         row2
        Row(self, [('7', self.gen_on_number_click('7')), 
                   ('8', self.gen_on_number_click('8')),
                   ('9', self.gen_on_number_click('9')),
                   ('X', self.gen_on_operator_click('*'))])
#         row.pack(side=TOP, expand=True, fill=BOTH)
     

#         row 3
        Row(self, [('4', self.gen_on_number_click('4')),
                  ('5', self.gen_on_number_click('5')),
                  ('6', self.gen_on_number_click('6')),
                  ('-', self.gen_on_operator_click('-'))])
#         row.pack(side=TOP, expand=True, fill=BOTH)
         
#         row 4
        Row(self, [('1', self.gen_on_number_click('1')),
                  ('2', self.gen_on_number_click('2')),
                  ('3', self.gen_on_number_click('3')),
                  ('+', self.gen_on_operator_click('+'))])
#         row.pack(side=TOP, expand=True, fill=BOTH)
#         self.add_button(row, '1', self.on_1_click)
       
        
#         row 5
        Row(self, [('+/-', self.on_nega_click),
                  ('0', self.gen_on_number_click('1')),
                  ('.', self.on_dot_click),
                  ('=', self.on_equal_click)])
#         row.pack(side=TOP, expand=True, fill=BOTH)
              
    
    
    def on_ce_click(self):
        print('ce clicked')
        
    def on_c_click(self):
        print('c clicked')
        
    def on_back_click(self):
        print('back clicked')
        
    def on_operator(self, operator):
        print('{} clicked.'.format(operator))
        if self.state == State.calculated:
            self.state = State.post_operator
        elif self.state == State.in_number1:  # 正在输入第一个数字
            self.state = State.post_operator
#         elif self.state == State.post_operator:  
        elif self.state == State.in_number2:
            self.on_equal_click()
            self.state = State.post_operator
        else: assert(0)
        
        self.operator = operator
    
    def on_division_click(self):
        self.on_operator('/')
        print('/ clicked')
        
    def on_plus_click(self):
        self.on_operator('+')
        print('plus clicked')
        
    def on_minus_click(self):
        self.on_operator('-')
        print('minus clicked')
        
    def on_x_click(self):
        self.on_operator('*')
        print('multiply clicked')
        
    def on_dot_click(self):
        self.on_number('.')
        print('dot clicked')
        
    def on_nega_click(self):
        print('+/- clicked')
        
    def on_equal_click(self):
        if self.state != State.in_number2:
            return
        print('equal clicked')
        if self.operator == '+':
            self.number1 = str(float(self.number1) + float(self.number2))
        elif self.operator == '-':
            self.number1 = str(float(self.number1) - float(self.number2))
        elif self.operator == '*':
            self.number1 = str(float(self.number1) * float(self.number2))
        elif self.operator == '/':
            self.number1 = str(float(self.number1) / float(self.number2))
        self.result_string.set(self.number1)
        self.state = State.calculated
        
#     def on_0_click(self):
#         print('0 clicked')
#         self.on_number('0')
        
    def gen_on_number_click(self, ch):
        return lambda: self.on_number(ch)
# 直接返回一个函数

    def gen_on_operator_click(self,ch):
        return lambda: self.on_operator(ch)
    
#     def on_1_click(self):
#         self.on_number('1')
#         print('1 clicked')
        
        
    def on_number(self, ch):
        if self.state == State.calculated:
            self.number1 = ch
            self.state = State.in_number1
            self.result_string.set(self.number1)
        elif self.state == State.in_number1:  # 正在输入第一个数字
            self.number1 = self.number1 + ch
            self.result_string.set(self.number1)
        elif self.state == State.post_operator:
            self.number2 = ch
            self.state = State.in_number2
            self.result_string.set(self.number2)
        elif self.state == State.in_number2:
            self.number2 = self.number2 + ch
            self.result_string.set(self.number2)
        else: assert(0)
        
    
if __name__=='__main__':
    app = Calculator()
    app.mainloop()
#     setup_ui()
# Out:
# * clicked.
# equal clicked

# %%
from tkinter import *
from tkinter import ttk
from enum import Enum

class State(Enum):
    calculated = 0
    in_number1 = 1
    post_operator = 2
    in_number2 = 3

class Row(Frame):
    def __init__(self, parent, buttons, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.pack(side=TOP, expand=True, fill=BOTH)
        for button in buttons:
            ttk.Button(self, text=button[0], command=button[1])\
            .pack(side=LEFT, expand=True, fill=BOTH)
        
    def add_button(self, text=None, command=None):
        button = ttk.Button(self, text=text, command=command)
        button.pack(side=LEFT,expand=True, fill=BOTH)
        return self
        
    
class Calculator(Tk):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        
        self.nmuber1 = '0'
        self.number2 = None
        self.operator = None
        self.state = State.calculated
        self.setup_ui()
        
    def setup_ui(self):
        self.title('Simple Calculator')
        self.geometry('400x600')
        
        self.result_string = StringVar()
        self.result_string.set('0')
        
        
#         Output
        output = ttk.Label(self, textvariable=self.result_string, 
                           font=('TKDefaultFont', 48), anchor=E)
        output.pack(side=TOP, expand=True, fill=BOTH)

#         row 1
        Row(self,[('CE', self.on_ce_click),
                 ('C', self.on_c_click),
                 ('Backspace', self.on_back_click),
                 ('/', self.gen_on_operator_click('/'))])
                
#         row2
        Row(self, [('7', self.gen_on_number_click('7')), 
                   ('8', self.gen_on_number_click('8')),
                   ('9', self.gen_on_number_click('9')),
                   ('X', self.gen_on_operator_click('*'))])
#         row.pack(side=TOP, expand=True, fill=BOTH)
     

#         row 3
        Row(self, [('4', self.gen_on_number_click('4')),
                  ('5', self.gen_on_number_click('5')),
                  ('6', self.gen_on_number_click('6')),
                  ('-', self.gen_on_operator_click('-'))])
#         row.pack(side=TOP, expand=True, fill=BOTH)
         
#         row 4
        Row(self, [('1', self.gen_on_number_click('1')),
                  ('2', self.gen_on_number_click('2')),
                  ('3', self.gen_on_number_click('3')),
                  ('+', self.gen_on_operator_click('+'))])
#         row.pack(side=TOP, expand=True, fill=BOTH)
#         self.add_button(row, '1', self.on_1_click)
       
        
#         row 5
        Row(self, [('+/-', self.on_nega_click),
                  ('0', self.gen_on_number_click('1')),
                  ('.', self.on_dot_click),
                  ('=', self.on_equal_click)])
#         row.pack(side=TOP, expand=True, fill=BOTH)
              
    
    
    def on_ce_click(self):
        print('ce clicked')
        
    def on_c_click(self):
        print('c clicked')
        
    def on_back_click(self):
        print('back clicked')
        
    def on_operator(self, operator):
        print('{} clicked.'.format(operator))
        if self.state == State.calculated:
            self.state = State.post_operator
        elif self.state == State.in_number1:  # 正在输入第一个数字
            self.state = State.post_operator
#         elif self.state == State.post_operator:  
        elif self.state == State.in_number2:
            self.on_equal_click()
            self.state = State.post_operator
        else: assert(0)
        
        self.operator = operator
    
    def on_division_click(self):
        self.on_operator('/')
        print('/ clicked')
        
    def on_plus_click(self):
        self.on_operator('+')
        print('plus clicked')
        
    def on_minus_click(self):
        self.on_operator('-')
        print('minus clicked')
        
    def on_x_click(self):
        self.on_operator('*')
        print('multiply clicked')
        
    def on_dot_click(self):
        self.on_number('.')
        print('dot clicked')
        
    def on_nega_click(self):
        print('+/- clicked')
        
    def on_equal_click(self):
        if self.state != State.in_number2:
            return
        print('equal clicked')
        if self.operator == '+':
            self.number1 = str(float(self.number1) + float(self.number2))
        elif self.operator == '-':
            self.number1 = str(float(self.number1) - float(self.number2))
        elif self.operator == '*':
            self.number1 = str(float(self.number1) * float(self.number2))
        elif self.operator == '/':
            self.number1 = str(float(self.number1) / float(self.number2))
            
        if int(float(self.number1)) == float(self.number1):
            self.result_string.set(int(self.number1)
        self.result_string.set(self.number1)
        self.state = State.calculated
        
#     def on_0_click(self):
#         print('0 clicked')
#         self.on_number('0')
        
    def gen_on_number_click(self, ch):
        return lambda: self.on_number(ch)
# 直接返回一个函数

    def gen_on_operator_click(self,ch):
        return lambda: self.on_operator(ch)
    
#     def on_1_click(self):
#         self.on_number('1')
#         print('1 clicked')
        
        
    def on_number(self, ch):
        if self.state == State.calculated:
            self.number1 = ch
            self.state = State.in_number1
            self.result_string.set(self.number1)
        elif self.state == State.in_number1:  # 正在输入第一个数字
            self.number1 = self.number1 + ch
            self.result_string.set(self.number1)
        elif self.state == State.post_operator:
            self.number2 = ch
            self.state = State.in_number2
            self.result_string.set(self.number2)
        elif self.state == State.in_number2:
            self.number2 = self.number2 + ch
            self.result_string.set(self.number2)
        else: assert(0)
        
    
if __name__=='__main__':
    app = Calculator()
    app.mainloop()
#     setup_ui()
# Out:
#   File "<ipython-input-16-4e8e447101e1>", line 150
#     self.state = State.calculated
#        ^
# SyntaxError: invalid syntax

# %%
from tkinter import *
from tkinter import ttk
from enum import Enum

class State(Enum):
    calculated = 0
    in_number1 = 1
    post_operator = 2
    in_number2 = 3

class Row(Frame):
    def __init__(self, parent, buttons, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.pack(side=TOP, expand=True, fill=BOTH)
        for button in buttons:
            ttk.Button(self, text=button[0], command=button[1])\
            .pack(side=LEFT, expand=True, fill=BOTH)
        
    def add_button(self, text=None, command=None):
        button = ttk.Button(self, text=text, command=command)
        button.pack(side=LEFT,expand=True, fill=BOTH)
        return self
        
    
class Calculator(Tk):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        
        self.nmuber1 = '0'
        self.number2 = None
        self.operator = None
        self.state = State.calculated
        self.setup_ui()
        
    def setup_ui(self):
        self.title('Simple Calculator')
        self.geometry('400x600')
        
        self.result_string = StringVar()
        self.result_string.set('0')
        
        
#         Output
        output = ttk.Label(self, textvariable=self.result_string, 
                           font=('TKDefaultFont', 48), anchor=E)
        output.pack(side=TOP, expand=True, fill=BOTH)

#         row 1
        Row(self,[('CE', self.on_ce_click),
                 ('C', self.on_c_click),
                 ('Backspace', self.on_back_click),
                 ('/', self.gen_on_operator_click('/'))])
                
#         row2
        Row(self, [('7', self.gen_on_number_click('7')), 
                   ('8', self.gen_on_number_click('8')),
                   ('9', self.gen_on_number_click('9')),
                   ('X', self.gen_on_operator_click('*'))])
#         row.pack(side=TOP, expand=True, fill=BOTH)
     

#         row 3
        Row(self, [('4', self.gen_on_number_click('4')),
                  ('5', self.gen_on_number_click('5')),
                  ('6', self.gen_on_number_click('6')),
                  ('-', self.gen_on_operator_click('-'))])
#         row.pack(side=TOP, expand=True, fill=BOTH)
         
#         row 4
        Row(self, [('1', self.gen_on_number_click('1')),
                  ('2', self.gen_on_number_click('2')),
                  ('3', self.gen_on_number_click('3')),
                  ('+', self.gen_on_operator_click('+'))])
#         row.pack(side=TOP, expand=True, fill=BOTH)
#         self.add_button(row, '1', self.on_1_click)
       
        
#         row 5
        Row(self, [('+/-', self.on_nega_click),
                  ('0', self.gen_on_number_click('1')),
                  ('.', self.on_dot_click),
                  ('=', self.on_equal_click)])
#         row.pack(side=TOP, expand=True, fill=BOTH)
              
    
    
    def on_ce_click(self):
        print('ce clicked')
        
    def on_c_click(self):
        print('c clicked')
        
    def on_back_click(self):
        print('back clicked')
        
    def on_operator(self, operator):
        print('{} clicked.'.format(operator))
        if self.state == State.calculated:
            self.state = State.post_operator
        elif self.state == State.in_number1:  # 正在输入第一个数字
            self.state = State.post_operator
#         elif self.state == State.post_operator:  
        elif self.state == State.in_number2:
            self.on_equal_click()
            self.state = State.post_operator
        else: assert(0)
        
        self.operator = operator
    
    def on_division_click(self):
        self.on_operator('/')
        print('/ clicked')
        
    def on_plus_click(self):
        self.on_operator('+')
        print('plus clicked')
        
    def on_minus_click(self):
        self.on_operator('-')
        print('minus clicked')
        
    def on_x_click(self):
        self.on_operator('*')
        print('multiply clicked')
        
    def on_dot_click(self):
        self.on_number('.')
        print('dot clicked')
        
    def on_nega_click(self):
        print('+/- clicked')
        
    def on_equal_click(self):
        if self.state != State.in_number2:
            return
        print('equal clicked')
        if self.operator == '+':
            self.number1 = str(float(self.number1) + float(self.number2))
        elif self.operator == '-':
            self.number1 = str(float(self.number1) - float(self.number2))
        elif self.operator == '*':
            self.number1 = str(float(self.number1) * float(self.number2))
        elif self.operator == '/':
            self.number1 = str(float(self.number1) / float(self.number2))
        self.result_string.set(self.number1)
        self.state = State.calculated
        
#     def on_0_click(self):
#         print('0 clicked')
#         self.on_number('0')
        
    def gen_on_number_click(self, ch):
        return lambda: self.on_number(ch)
# 直接返回一个函数

    def gen_on_operator_click(self,ch):
        return lambda: self.on_operator(ch)
    
#     def on_1_click(self):
#         self.on_number('1')
#         print('1 clicked')
        
    def is_valid(self, number_string):
        
        try:
            float(number_string)
            return True
        except:
            return False
    
    def on_number(self, ch):
        print(self.state)
        if self.state == State.calculated:
            self.number1 = ch
            self.state = State.in_number1
            self.result_string.set(self.number1)
        elif self.state == State.in_number1:  # 正在输入第一个数字
            if self.is_valid(self.number1 + ch):
                self.number1 = self.number1 + ch
                self.result_string.set(self.number1)
        elif self.state == State.post_operator:
            self.number2 = ch
            self.state = State.in_number2
            self.result_string.set(self.number2)
        elif self.state == State.in_number2:
            if self.is_valid(self.number2 + ch):
                self.number2 = self.number2 + ch
                self.result_string.set(self.number2)
        else: assert(0)
        
    
if __name__=='__main__':
    app = Calculator()
    app.mainloop()

# %%
from tkinter import *
from tkinter import ttk
from enum import Enum

class State(Enum):
    calculated = 0
    in_number = 1
    post_operator = 2

class Row(Frame):
    def __init__(self, parent, buttons, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.pack(side=TOP, expand=True, fill=BOTH)
        for button in buttons:
            ttk.Button(self, text=button[0], command=button[1])\
            .pack(side=LEFT, expand=True, fill=BOTH)
        
    def add_button(self, text=None, command=None):
        button = ttk.Button(self, text=text, command=command)
        button.pack(side=LEFT,expand=True, fill=BOTH)
        return self
        
    
class Calculator(Tk):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        
        self.nmuber1 = '0'
        self.number2 = None
        self.operator = None
        self.state = State.calculated
        self.setup_ui()
        
    def setup_ui(self):
        self.title('Simple Calculator')
        self.geometry('400x600')
        
        self.result_string = StringVar()
        self.result_string.set('0')
        
        
#         Output
        output = ttk.Label(self, textvariable=self.result_string, 
                           font=('TKDefaultFont', 48), anchor=E)
        output.pack(side=TOP, expand=True, fill=BOTH)

#         row 1
        Row(self,[('CE', self.on_ce_click),
                 ('C', self.on_c_click),
                 ('Backspace', self.on_back_click),
                 ('/', self.gen_on_operator_click('/'))])
                
#         row2
        Row(self, [('7', self.gen_on_number_click('7')), 
                   ('8', self.gen_on_number_click('8')),
                   ('9', self.gen_on_number_click('9')),
                   ('X', self.gen_on_operator_click('*'))])
#         row.pack(side=TOP, expand=True, fill=BOTH)
     

#         row 3
        Row(self, [('4', self.gen_on_number_click('4')),
                  ('5', self.gen_on_number_click('5')),
                  ('6', self.gen_on_number_click('6')),
                  ('-', self.gen_on_operator_click('-'))])
#         row.pack(side=TOP, expand=True, fill=BOTH)
         
#         row 4
        Row(self, [('1', self.gen_on_number_click('1')),
                  ('2', self.gen_on_number_click('2')),
                  ('3', self.gen_on_number_click('3')),
                  ('+', self.gen_on_operator_click('+'))])
#         row.pack(side=TOP, expand=True, fill=BOTH)
#         self.add_button(row, '1', self.on_1_click)
       
        
#         row 5
        Row(self, [('+/-', self.on_nega_click),
                  ('0', self.gen_on_number_click('1')),
                  ('.', self.on_dot_click),
                  ('=', self.on_equal_click)])
#         row.pack(side=TOP, expand=True, fill=BOTH)
              
    
    
    def on_ce_click(self):
        print('ce clicked')
        
    def on_c_click(self):
        print('c clicked')
        
    def on_back_click(self):
        print('back clicked')
        
    def on_operator(self, operator):
        print('{} clicked.'.format(operator))
        if self.state == State.calculated:
            self.state = State.post_operator
        elif self.state == State.in_number1:  # 正在输入第一个数字
            self.state = State.post_operator
#         elif self.state == State.post_operator:  
        elif self.state == State.in_number2:
            self.on_equal_click()
            self.state = State.post_operator
        else: assert(0)
        
        self.operator = operator
    
    def on_division_click(self):
        self.on_operator('/')
        print('/ clicked')
        
    def on_plus_click(self):
        self.on_operator('+')
        print('plus clicked')
        
    def on_minus_click(self):
        self.on_operator('-')
        print('minus clicked')
        
    def on_x_click(self):
        self.on_operator('*')
        print('multiply clicked')
        
    def on_dot_click(self):
        self.on_number('.')
        print('dot clicked')
        
    def on_nega_click(self):
        print('+/- clicked')
        
    def on_equal_click(self):
        if self.state != State.in_number2:
            return
        print('equal clicked')
        if self.operator == '+':
            self.number1 = str(float(self.number1) + float(self.number2))
        elif self.operator == '-':
            self.number1 = str(float(self.number1) - float(self.number2))
        elif self.operator == '*':
            self.number1 = str(float(self.number1) * float(self.number2))
        elif self.operator == '/':
            self.number1 = str(float(self.number1) / float(self.number2))
        self.result_string.set(self.number1)
        self.state = State.calculated
        
#     def on_0_click(self):
#         print('0 clicked')
#         self.on_number('0')
        
    def gen_on_number_click(self, ch):
        return lambda: self.on_number(ch)
# 直接返回一个函数

    def gen_on_operator_click(self,ch):
        return lambda: self.on_operator(ch)
    
#     def on_1_click(self):
#         self.on_number('1')
#         print('1 clicked')
        
    def is_valid(self, number_string):
        
        try:
            float(number_string)
            return True
        except:
            return False
    
    def on_number(self, ch):
        print(self.state)
        if self.state == State.calculated:
            self.number1 = ch
            self.state = State.in_number1
            self.result_string.set(self.number1)
        elif self.state == State.in_number1:  # 正在输入第一个数字
            if self.is_valid(self.number1 + ch):
                self.number1 = self.number1 + ch
                self.result_string.set(self.number1)
        elif self.state == State.post_operator:
            self.number2 = ch
            self.state = State.in_number2
            self.result_string.set(self.number2)
        elif self.state == State.in_number2:
            if self.is_valid(self.number2 + ch):
                self.number2 = self.number2 + ch
                self.result_string.set(self.number2)
        else: assert(0)
        
    
if __name__=='__main__':
    app = Calculator()
    app.mainloop()
